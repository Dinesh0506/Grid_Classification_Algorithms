# %%
#importing the Libraies
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#read the data set 
dataset=pd.read_csv("Social_Network_Ads.csv")

# %%
#print the data set 
dataset
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
#converting categorical data to numerical data
dataset=pd.get_dummies(dataset,drop_first=True)

# %%
#Removing the unwanted cloumns from table
dataset=dataset.drop("User ID",axis=1)

# %%
dataset
# Out:
#      Age  EstimatedSalary  Purchased  Gender_Male
# 0     19            19000          0            1
# 1     35            20000          0            1
# 2     26            43000          0            0
# 3     27            57000          0            0
# 4     19            76000          0            1
# ..   ...              ...        ...          ...
# 395   46            41000          1            0
# 396   51            23000          1            1
# 397   50            20000          1            0
# 398   36            33000          0            1
# 399   49            36000          1            0
#
# [400 rows x 4 columns]

# %%
#input and output Split form data 
indep=dataset[["Age","EstimatedSalary","Gender_Male"]]
dep=dataset["Purchased"]

# %%
#split into training set and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(indep, dep, test_size = 1/3, random_state = 0)

# %%
#standardize the value using StandardScaler
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
param_grid = {'solver':['newton-cg', 'lbfgs', 'liblinear', 'saga'],'penalty':['l1','l2','elasticnet',None],
              'multi_class':['auto', 'ovr', 'multinomial']} 
grid = GridSearchCV(LogisticRegression(), param_grid,refit = True, verbose = 3,n_jobs=-1,scoring='f1_weighted') 
# fitting the model for grid search 
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py:372: FitFailedWarning:
# 160 fits failed out of a total of 240.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 447, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 457, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 15 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1471, in fit
#     raise ValueError(
# ValueError: l1_ratio must be between 0 and 1; got (l1_ratio=None)
#
# --------------------------------------------------------------------------------
# 60 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1461, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 441, in _check_solver
#     raise ValueError(
# ValueError: Logistic Regression supports only penalties in ['l1', 'l2', 'elasticnet', 'none'], got None.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Anconda\lib\site-packages\sklearn\model_selection\_validation.py", line 680, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 1519, in fit
#     multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#   File "C:\Anconda\lib\site-packages\sklearn\linear_model\_logistic.py", line 483, in _check_multi_class
#     raise ValueError("Solver %s does not support a multinomial backend." % solver)
# ValueError: Solver liblinear does not support a multinomial backend.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Anconda\lib\site-packages\sklearn\model_selection\_search.py:969: UserWarning: One or more of the test scores are non-finite: [       nan        nan 0.82554202 0.82876593 0.82773722 0.82773722
#  0.82876593 0.82773722        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.82554202 0.82876593 0.82773722 0.82773722 0.82876593 0.82773722
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.82876593
#  0.82876593 0.82876593        nan 0.82876593        nan        nan
#         nan        nan        nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'multi_class': ['auto', 'ovr', 'multinomial'],
#                          'penalty': ['l1', 'l2', 'elasticnet', None],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'saga']},
#              scoring='f1_weighted', verbose=3)

# %%
# print best parameter after tuning 
#print(grid.best_params_) 
re=grid.cv_results_
#print(re)
grid_predictions = grid.predict(X_test) 
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, grid_predictions)
print(cm)
# print classification report 
from sklearn.metrics import classification_report
clf_report = classification_report(y_test, grid_predictions)
print(clf_report)
# Out:
# [[79  6]
#  [10 39]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91        85
#            1       0.87      0.80      0.83        49
#
#     accuracy                           0.88       134
#    macro avg       0.88      0.86      0.87       134
# weighted avg       0.88      0.88      0.88       134

# %%
#Calculate the F1Score 
from sklearn.metrics import f1_score
f1_macro=f1_score(y_test,grid_predictions,average='weighted')
print("The f1_macro value for best parameter {}:".format(grid.best_params_),f1_macro)
# Out:
# The f1_macro value for best parameter {'multi_class': 'auto', 'penalty': 'l1', 'solver': 'saga'}: 0.8794289739855382

# %%
#calculate the roc_auc_score 
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,grid.predict_proba(X_test)[:,1])
# Out:
# 0.9493397358943578

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.000785      0.001571         0.000000        0.000000
# 1        0.000000      0.000000         0.000000        0.000000
# 2        0.002944      0.002651         0.001523        0.003047
# 3        0.003877      0.002523         0.001307        0.001990
# 4        0.009767      0.002572         0.001837        0.002514
# 5        0.005767      0.005940         0.003375        0.006750
# 6        0.001703      0.003406         0.003146        0.005078
# 7        0.003251      0.004326         0.001979        0.002613
# 8        0.000000      0.000000         0.000000        0.000000
# 9        0.000199      0.000397         0.000000        0.000000
# 10       0.000000      0.000000         0.000000        0.000000
# 11       0.000266      0.000532         0.000000        0.000000
# 12       0.000133      0.000267         0.000000        0.000000
# 13       0.003356      0.004110         0.000000        0.000000
# 14       0.000000      0.000000         0.000000        0.000000
# 15       0.000000      0.000000         0.000000        0.000000
# 16       0.001386      0.002407         0.000000        0.000000
# 17       0.001006      0.001522         0.000000        0.000000
# 18       0.002263      0.003409         0.002263        0.003409
# 19       0.003854      0.004396         0.002905        0.004768
# 20       0.012653      0.009220         0.000253        0.000506
# 21       0.002123      0.002880         0.007756        0.006559
# 22       0.003199      0.005208         0.004569        0.003367
# 23       0.003190      0.001830         0.000692        0.001383
# 24       0.000514      0.001028         0.000000        0.000000
# 25       0.000954      0.001908         0.000000        0.000000
# 26       0.000000      0.000000         0.000000        0.000000
# 27       0.000589      0.000943         0.000000        0.000000
# 28       0.001341      0.001219         0.000000        0.000000
# 29       0.000434      0.000539         0.000000        0.000000
# 30       0.000858      0.001080         0.000000        0.000000
# 31       0.000746      0.000670         0.000000        0.000000
# 32       0.001403      0.001458         0.000000        0.000000
# 33       0.000508      0.000783         0.000000        0.000000
# 34       0.003168      0.000929         0.000000        0.000000
# 35       0.004266      0.004607         0.000854        0.001708
# 36       0.034824      0.036943         0.000000        0.000000
# 37       0.016147      0.025912         0.000406        0.000812
# 38       0.002921      0.005494         0.000000        0.000000
# 39       0.005163      0.002832         0.001949        0.001894
# 40       0.001515      0.003031         0.000000        0.000000
# 41       0.002588      0.002250         0.000000        0.000000
# 42       0.000000      0.000000         0.000000        0.000000
# 43       0.000565      0.000791         0.000000        0.000000
# 44       0.000000      0.000000         0.000000        0.000000
# 45       0.002704      0.005408         0.000000        0.000000
# 46       0.000904      0.001808         0.000000        0.000000
# 47       0.000000      0.000000         0.000000        0.000000
#
#    param_multi_class param_penalty param_solver  \
# 0               auto            l1    newton-cg
# 1               auto            l1        lbfgs
# 2               auto            l1    liblinear
# 3               auto            l1         saga
# 4               auto            l2    newton-cg
# 5               auto            l2        lbfgs
# 6               auto            l2    liblinear
# 7               auto            l2         saga
# 8               auto    elasticnet    newton-cg
# 9               auto    elasticnet        lbfgs
# 10              auto    elasticnet    liblinear
# 11              auto    elasticnet         saga
# 12              auto          None    newton-cg
# 13              auto          None        lbfgs
# 14              auto          None    liblinear
# 15              auto          None         saga
# 16               ovr            l1    newton-cg
# 17               ovr            l1        lbfgs
# 18               ovr            l1    liblinear
# 19               ovr            l1         saga
# 20               ovr            l2    newton-cg
# 21               ovr            l2        lbfgs
# 22               ovr            l2    liblinear
# 23               ovr            l2         saga
# 24               ovr    elasticnet    newton-cg
# 25               ovr    elasticnet        lbfgs
# 26               ovr    elasticnet    liblinear
# 27               ovr    elasticnet         saga
# 28               ovr          None    newton-cg
# 29               ovr          None        lbfgs
# 30               ovr          None    liblinear
# 31               ovr          None         saga
# 32       multinomial            l1    newton-cg
# 33       multinomial            l1        lbfgs
# 34       multinomial            l1    liblinear
# 35       multinomial            l1         saga
# 36       multinomial            l2    newton-cg
# 37       multinomial            l2        lbfgs
# 38       multinomial            l2    liblinear
# 39       multinomial            l2         saga
# 40       multinomial    elasticnet    newton-cg
# 41       multinomial    elasticnet        lbfgs
# 42       multinomial    elasticnet    liblinear
# 43       multinomial    elasticnet         saga
# 44       multinomial          None    newton-cg
# 45       multinomial          None        lbfgs
# 46       multinomial          None    liblinear
# 47       multinomial          None         saga
#
#                                                params  split0_test_score  \
# 0   {'multi_class': 'auto', 'penalty': 'l1', 'solv...                NaN
# 1   {'multi_class': 'auto', 'penalty': 'l1', 'solv...                NaN
# 2   {'multi_class': 'auto', 'penalty': 'l1', 'solv...           0.804764
# 3   {'multi_class': 'auto', 'penalty': 'l1', 'solv...           0.804764
# 4   {'multi_class': 'auto', 'penalty': 'l2', 'solv...           0.799620
# 5   {'multi_class': 'auto', 'penalty': 'l2', 'solv...           0.799620
# 6   {'multi_class': 'auto', 'penalty': 'l2', 'solv...           0.804764
# 7   {'multi_class': 'auto', 'penalty': 'l2', 'solv...           0.799620
# 8   {'multi_class': 'auto', 'penalty': 'elasticnet...                NaN
# 9   {'multi_class': 'auto', 'penalty': 'elasticnet...                NaN
# 10  {'multi_class': 'auto', 'penalty': 'elasticnet...                NaN
# 11  {'multi_class': 'auto', 'penalty': 'elasticnet...                NaN
# 12  {'multi_class': 'auto', 'penalty': None, 'solv...                NaN
# 13  {'multi_class': 'auto', 'penalty': None, 'solv...                NaN
# 14  {'multi_class': 'auto', 'penalty': None, 'solv...                NaN
# 15  {'multi_class': 'auto', 'penalty': None, 'solv...                NaN
# 16  {'multi_class': 'ovr', 'penalty': 'l1', 'solve...                NaN
# 17  {'multi_class': 'ovr', 'penalty': 'l1', 'solve...                NaN
# 18  {'multi_class': 'ovr', 'penalty': 'l1', 'solve...           0.804764
# 19  {'multi_class': 'ovr', 'penalty': 'l1', 'solve...           0.804764
# 20  {'multi_class': 'ovr', 'penalty': 'l2', 'solve...           0.799620
# 21  {'multi_class': 'ovr', 'penalty': 'l2', 'solve...           0.799620
# 22  {'multi_class': 'ovr', 'penalty': 'l2', 'solve...           0.804764
# 23  {'multi_class': 'ovr', 'penalty': 'l2', 'solve...           0.799620
# 24  {'multi_class': 'ovr', 'penalty': 'elasticnet'...                NaN
# 25  {'multi_class': 'ovr', 'penalty': 'elasticnet'...                NaN
# 26  {'multi_class': 'ovr', 'penalty': 'elasticnet'...                NaN
# 27  {'multi_class': 'ovr', 'penalty': 'elasticnet'...                NaN
# 28  {'multi_class': 'ovr', 'penalty': None, 'solve...                NaN
# 29  {'multi_class': 'ovr', 'penalty': None, 'solve...                NaN
# 30  {'multi_class': 'ovr', 'penalty': None, 'solve...                NaN
# 31  {'multi_class': 'ovr', 'penalty': None, 'solve...                NaN
# 32  {'multi_class': 'multinomial', 'penalty': 'l1'...                NaN
# 33  {'multi_class': 'multinomial', 'penalty': 'l1'...                NaN
# 34  {'multi_class': 'multinomial', 'penalty': 'l1'...                NaN
# 35  {'multi_class': 'multinomial', 'penalty': 'l1'...           0.804764
# 36  {'multi_class': 'multinomial', 'penalty': 'l2'...           0.804764
# 37  {'multi_class': 'multinomial', 'penalty': 'l2'...           0.804764
# 38  {'multi_class': 'multinomial', 'penalty': 'l2'...                NaN
# 39  {'multi_class': 'multinomial', 'penalty': 'l2'...           0.804764
# 40  {'multi_class': 'multinomial', 'penalty': 'ela...                NaN
# 41  {'multi_class': 'multinomial', 'penalty': 'ela...                NaN
# 42  {'multi_class': 'multinomial', 'penalty': 'ela...                NaN
# 43  {'multi_class': 'multinomial', 'penalty': 'ela...                NaN
# 44  {'multi_class': 'multinomial', 'penalty': None...                NaN
# 45  {'multi_class': 'multinomial', 'penalty': None...                NaN
# 46  {'multi_class': 'multinomial', 'penalty': None...                NaN
# 47  {'multi_class': 'multinomial', 'penalty': None...                NaN
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0                 NaN                NaN                NaN
# 1                 NaN                NaN                NaN
# 2            0.811321            0.66593            0.92351
# 3            0.811321            0.68205            0.92351
# 4            0.811321            0.68205            0.92351
# 5            0.811321            0.68205            0.92351
# 6            0.811321            0.68205            0.92351
# 7            0.811321            0.68205            0.92351
# 8                 NaN                NaN                NaN
# 9                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 12                NaN                NaN                NaN
# 13                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 16                NaN                NaN                NaN
# 17                NaN                NaN                NaN
# 18           0.811321            0.66593            0.92351
# 19           0.811321            0.68205            0.92351
# 20           0.811321            0.68205            0.92351
# 21           0.811321            0.68205            0.92351
# 22           0.811321            0.68205            0.92351
# 23           0.811321            0.68205            0.92351
# 24                NaN                NaN                NaN
# 25                NaN                NaN                NaN
# 26                NaN                NaN                NaN
# 27                NaN                NaN                NaN
# 28                NaN                NaN                NaN
# 29                NaN                NaN                NaN
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
# 32                NaN                NaN                NaN
# 33                NaN                NaN                NaN
# 34                NaN                NaN                NaN
# 35           0.811321            0.68205            0.92351
# 36           0.811321            0.68205            0.92351
# 37           0.811321            0.68205            0.92351
# 38                NaN                NaN                NaN
# 39           0.811321            0.68205            0.92351
# 40                NaN                NaN                NaN
# 41                NaN                NaN                NaN
# 42                NaN                NaN                NaN
# 43                NaN                NaN                NaN
# 44                NaN                NaN                NaN
# 45                NaN                NaN                NaN
# 46                NaN                NaN                NaN
# 47                NaN                NaN                NaN
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 NaN              NaN             NaN               30
# 1                 NaN              NaN             NaN               32
# 2            0.922185         0.825542        0.094918               15
# 3            0.922185         0.828766        0.089565                1
# 4            0.922185         0.827737        0.089864                9
# 5            0.922185         0.827737        0.089864                9
# 6            0.922185         0.828766        0.089565                1
# 7            0.922185         0.827737        0.089864                9
# 8                 NaN              NaN             NaN               33
# 9                 NaN              NaN             NaN               34
# 10                NaN              NaN             NaN               35
# 11                NaN              NaN             NaN               36
# 12                NaN              NaN             NaN               37
# 13                NaN              NaN             NaN               38
# 14                NaN              NaN             NaN               39
# 15                NaN              NaN             NaN               40
# 16                NaN              NaN             NaN               41
# 17                NaN              NaN             NaN               42
# 18           0.922185         0.825542        0.094918               15
# 19           0.922185         0.828766        0.089565                1
# 20           0.922185         0.827737        0.089864                9
# 21           0.922185         0.827737        0.089864                9
# 22           0.922185         0.828766        0.089565                1
# 23           0.922185         0.827737        0.089864                9
# 24                NaN              NaN             NaN               44
# 25                NaN              NaN             NaN               45
# 26                NaN              NaN             NaN               46
# 27                NaN              NaN             NaN               31
# 28                NaN              NaN             NaN               47
# 29                NaN              NaN             NaN               29
# 30                NaN              NaN             NaN               28
# 31                NaN              NaN             NaN               18
# 32                NaN              NaN             NaN               17
# 33                NaN              NaN             NaN               20
# 34                NaN              NaN             NaN               19
# 35           0.922185         0.828766        0.089565                1
# 36           0.922185         0.828766        0.089565                1
# 37           0.922185         0.828766        0.089565                1
# 38                NaN              NaN             NaN               21
# 39           0.922185         0.828766        0.089565                1
# 40                NaN              NaN             NaN               22
# 41                NaN              NaN             NaN               23
# 42                NaN              NaN             NaN               24
# 43                NaN              NaN             NaN               25
# 44                NaN              NaN             NaN               26
# 45                NaN              NaN             NaN               27
# 46                NaN              NaN             NaN               43
# 47                NaN              NaN             NaN               48

# %%
Age_input=float(input("Age:"))
EstimatedSalary_input=float(input("EstimatedSalary:"))
Gender_Male_input=float(input("Gender_Male:"))
# Out:
# Age:25
# EstimatedSalary:15000
# Gender_Male:1

# %%
Purchase_Prediction=grid.predict([[Age_input,EstimatedSalary_input,Gender_Male_input]])
print("Purchase_Prediction={}".format(Purchase_Prediction))
# Out:
# Purchase_Prediction=[1]
